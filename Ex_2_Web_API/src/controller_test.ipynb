# %%
import residencias_controller as rc
import media_preco_controller as mpc

# %% [markdown]
# Testar **residencias_controller**

# %%
rc.get_all()
# Out:
# [(2539,
#   'Clean & quiet apt home by the park',
#   2787,
#   'John',
#   'Kensington',
#   40.647490000000005,
#   -73.97237,
#   'Private room',
#   149,
#   1,
#   9,
#   '2018-10-19',
#   0.21,
#   6,
#   365,
#   'Brooklyn'),
#  (63546,
#   'Large and Cozy Private Bedroom',
#   308652,
#   'Antonín',
#   'Kensington',
#   40.64106,
#   -73.97426,
#   'Private room',
#   39,
#   1,
#   45,
#   '2019-05-16',
#   0.46,
#   2,
#   365,
#   'Brooklyn'),
#  (125594,
#   'SUPER BIG AND COZY PRIVATE BEDROOM',
#   308652,
#   'Antonín',
#   'Kensington',
#   40.64302,
#   -73.97255,
#   'Private room',
#   39,
#   1,
#   82,
#   '2019-05-19',
#   0.94,
#   2,
#   365,
#   'Brooklyn'),
#  (267652,
#   'Private clean pleasant spacious room.',
#   164675,
#   'Janice',
#   'Kensington',
#   40.64277,
#   -73.97296,
#   'Private room',
#   60,
#   2,
#   20,
#   '2019-01-21',
#   0.42,
#   1,
#   347,
#   'Brooklyn'),
#  (282341,
#   'Kensington/Ditmas Park pied-a-terre',
#   1471384,
# ...

# %%
rc.get_by_neighbourhood_group("Brooklyn")
# Out:
# [(2539,
#   'Clean & quiet apt home by the park',
#   2787,
#   'John',
#   'Kensington',
#   40.647490000000005,
#   -73.97237,
#   'Private room',
#   149,
#   1,
#   9,
#   '2018-10-19',
#   0.21,
#   6,
#   365,
#   'Brooklyn'),
#  (63546,
#   'Large and Cozy Private Bedroom',
#   308652,
#   'Antonín',
#   'Kensington',
#   40.64106,
#   -73.97426,
#   'Private room',
#   39,
#   1,
#   45,
#   '2019-05-16',
#   0.46,
#   2,
#   365,
#   'Brooklyn'),
#  (125594,
#   'SUPER BIG AND COZY PRIVATE BEDROOM',
#   308652,
#   'Antonín',
#   'Kensington',
#   40.64302,
#   -73.97255,
#   'Private room',
#   39,
#   1,
#   82,
#   '2019-05-19',
#   0.94,
#   2,
#   365,
#   'Brooklyn'),
#  (267652,
#   'Private clean pleasant spacious room.',
#   164675,
#   'Janice',
#   'Kensington',
#   40.64277,
#   -73.97296,
#   'Private room',
#   60,
#   2,
#   20,
#   '2019-01-21',
#   0.42,
#   1,
#   347,
#   'Brooklyn'),
#  (282341,
#   'Kensington/Ditmas Park pied-a-terre',
#   1471384,
# ...

# %%
rc.insert_like(2539,1)
# Out:
# True

# %% [markdown]
# Testar **media_preco_controller**

# %%
mpc.get_all()
# Out:
# [('Brooklyn', 'Entire home/apt', 171.28189729133473),
#  ('Brooklyn', 'Private room', 73.34956195244055),
#  ('Brooklyn', 'Shared room', 45.45862068965517),
#  ('Manhattan', 'Entire home/apt', 230.20096366191527),
#  ('Manhattan', 'Private room', 106.60748849754086),
#  ('Manhattan', 'Shared room', 77.98033707865169),
#  ('Queens', 'Entire home/apt', 139.2256027554535),
#  ('Queens', 'Private room', 69.30283793876026),
#  ('Queens', 'Shared room', 64.46710526315789),
#  ('Staten Island', 'Entire home/apt', 125.36666666666666),
#  ('Staten Island', 'Private room', 57.58490566037736),
#  ('Staten Island', 'Shared room', 57.6)]

# %%
mpc.get_by_neighbourhood_group("Brooklyn")
# Out:
# [('Brooklyn', 'Entire home/apt', 171.28189729133473),
#  ('Brooklyn', 'Private room', 73.34956195244055),
#  ('Brooklyn', 'Shared room', 45.45862068965517)]

# %%
mpc.get_by_room_type("Entire home/apt")
# Out:
# [('Brooklyn', 'Entire home/apt', 171.28189729133473),
#  ('Manhattan', 'Entire home/apt', 230.20096366191527),
#  ('Queens', 'Entire home/apt', 139.2256027554535),
#  ('Staten Island', 'Entire home/apt', 125.36666666666666)]
